# %%
import numpy as np
import pandas as pd
import requests
import matplotlib.pyplot as plt
import seaborn as sn
import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import warnings

# %%
# Suppress UserWarning
warnings.filterwarnings("ignore", category=UserWarning)

# %%
df_trips = pd.read_csv('trips_1.5M.csv')
df_trips.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-06-03 10:41:50   2015-06-03 11:08:33                1
# 1         2  2015-02-14 19:38:55   2015-02-14 20:00:59                1
# 2         2  2015-04-21 15:21:04   2015-04-21 15:33:38                1
# 3         2  2015-01-29 18:58:54   2015-01-29 19:04:46                3
# 4         1  2015-06-05 10:47:29   2015-06-05 10:58:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           2.80        -73.952888        40.776814           1
# 1           2.79        -73.995827        40.725353           1
# 2           1.75        -73.951920        40.769421           1
# 3           0.83        -74.009026        40.715710           1
# 4           0.80        -73.985909        40.756176           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.979034         40.756611             1
# 1                  N         -73.984314         40.757389             2
# 2                  N         -73.956421         40.787140             2
# 3                  N         -74.003418         40.723152             1
# 4                  N         -73.988358         40.747398             2
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  total_amount
# 0         17.5    0.0      0.5        4.57           0.0         22.87
# 1         15.0    0.0      0.5        0.00           0.0         15.80
# 2          9.5    0.0      0.5        0.00           0.0         10.30
# 3          5.5    1.0      0.5        1.46           0.0          8.76
# 4          7.0    0.0      0.5        0.00           0.0          7.80

# %% [markdown]
# # Memory usage optimization

# %%
df_trips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1500000 non-null  int64
#  1   tpep_pickup_datetime   1500000 non-null  object
#  2   tpep_dropoff_datetime  1500000 non-null  object
#  3   passenger_count        1500000 non-null  int64
#  4   trip_distance          1500000 non-null  float64
#  5   pickup_longitude       1500000 non-null  float64
#  6   pickup_latitude        1500000 non-null  float64
#  7   RateCodeID             1500000 non-null  int64
#  8   store_and_fwd_flag     1500000 non-null  object
#  9   dropoff_longitude      1500000 non-null  float64
#  10  dropoff_latitude       1500000 non-null  float64
#  11  payment_type           1500000 non-null  int64
#  12  fare_amount            1500000 non-null  float64
#  13  extra                  1500000 non-null  float64
#  14  mta_tax                1500000 non-null  float64
#  15  tip_amount             1500000 non-null  float64
#  16  tolls_amount           1500000 non-null  float64
#  17  total_amount           1500000 non-null  float64
# dtypes: float64(11), int64(4), object(3)
# memory usage: 206.0+ MB

# %%
# To reduce memory usage, we will limit the datatypes of the columns
df_trips[['VendorID', 'passenger_count', 'RateCodeID', 'payment_type']] = df_trips[['VendorID', 'passenger_count', 'RateCodeID', 'payment_type']].astype('int8')
df_trips[['fare_amount','dropoff_longitude', 'dropoff_latitude', 'pickup_longitude', 'pickup_latitude', 'extra', 'mta_tax', 'tip_amount','tolls_amount' ]] = df_trips[['fare_amount','dropoff_longitude', 'dropoff_latitude', 'pickup_longitude', 'pickup_latitude', 'extra', 'mta_tax', 'tip_amount','tolls_amount']].astype('float16')
df_trips['total_amount'] = df_trips['total_amount'].astype('float32')
df_trips['trip_distance'] = df_trips['trip_distance'].astype('float16')
df_trips.info()
# Out:
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\dtypes\astype.py:134: RuntimeWarning: overflow encountered in cast
#   return arr.astype(dtype, copy=True)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500000 entries, 0 to 1499999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   VendorID               1500000 non-null  int8
#  1   tpep_pickup_datetime   1500000 non-null  object
#  2   tpep_dropoff_datetime  1500000 non-null  object
#  3   passenger_count        1500000 non-null  int8
#  4   trip_distance          1500000 non-null  float16
#  5   pickup_longitude       1500000 non-null  float16
#  6   pickup_latitude        1500000 non-null  float16
#  7   RateCodeID             1500000 non-null  int8
#  8   store_and_fwd_flag     1500000 non-null  object
#  9   dropoff_longitude      1500000 non-null  float16
#  10  dropoff_latitude       1500000 non-null  float16
#  11  payment_type           1500000 non-null  int8
#  12  fare_amount            1500000 non-null  float16
#  13  extra                  1500000 non-null  float16
#  14  mta_tax                1500000 non-null  float16
#  15  tip_amount             1500000 non-null  float16
#  16  tolls_amount           1500000 non-null  float16
#  17  total_amount           1500000 non-null  float32
# dtypes: float16(10), float32(1), int8(4), object(3)
# memory usage: 74.4+ MB

# %% [markdown]
# # Data cleaning

# %% [markdown]
# ## Adding the trip distance length in time units

# %%
# To predict the values, we will need to use the trip distances in time units, which we currently do not have
# We can do this based on the two datetime columns

# First, turning the two columns into datetime objects
df_trips["tpep_pickup_datetime"] = pd.to_datetime(df_trips["tpep_pickup_datetime"])
df_trips["tpep_dropoff_datetime"] = pd.to_datetime(df_trips["tpep_dropoff_datetime"])

# Then, we can calculate the time length of the trip
df_trips['time_length'] = (df_trips["tpep_dropoff_datetime"] - df_trips["tpep_pickup_datetime"]).dt.total_seconds() / 3600
df_trips = df_trips.drop(columns=['tpep_dropoff_datetime', 'tpep_pickup_datetime', 'store_and_fwd_flag'])

df_trips
# Out:
#          VendorID  passenger_count  trip_distance  pickup_longitude  \
# 0               1                1       2.800781          -73.9375
# 1               2                1       2.789062          -74.0000
# 2               2                1       1.750000          -73.9375
# 3               2                3       0.830078          -74.0000
# 4               1                3       0.799805          -74.0000
# ...           ...              ...            ...               ...
# 1499995         1                1       0.700195          -74.0000
# 1499996         1                1       0.799805          -74.0000
# 1499997         1                1       2.000000          -73.9375
# 1499998         2                1       1.959961          -74.0000
# 1499999         2                2       0.950195          -74.0000
#
#          pickup_latitude  RateCodeID  dropoff_longitude  dropoff_latitude  \
# 0               40.78125           1           -74.0000          40.75000
# 1               40.71875           1           -74.0000          40.75000
# 2               40.78125           1           -73.9375          40.78125
# 3               40.71875           1           -74.0000          40.71875
# 4               40.75000           1           -74.0000          40.75000
# ...                  ...         ...                ...               ...
# 1499995         40.75000           1           -74.0000          40.75000
# 1499996         40.75000           1           -74.0000          40.75000
# 1499997         40.78125           1           -74.0000          40.75000
# 1499998         40.71875           1           -74.0000          40.75000
# 1499999         40.75000           1           -74.0000          40.75000
#
#          payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0                   1         17.5    0.0      0.5    4.570312           0.0
# 1                   2         15.0    0.0      0.5    0.000000           0.0
# 2                   2          9.5    0.0      0.5    0.000000           0.0
# 3                   1          5.5    1.0      0.5    1.459961           0.0
# 4                   2          7.0    0.0      0.5    0.000000           0.0
# ...               ...          ...    ...      ...         ...           ...
# 1499995             1          4.5    0.0      0.5    1.549805           0.0
# 1499996             1          4.5    0.5      0.5    1.000000           0.0
# 1499997             1          9.5    0.0      0.5    2.050781           0.0
# 1499998             1         12.0    1.0      0.5    2.759766           0.0
# 1499999             1          7.5    0.5      0.5    2.199219           0.0
#
#          total_amount  time_length
# 0           22.870001     0.445278
# 1           15.800000     0.367778
# 2           10.300000     0.209444
# 3            8.760000     0.097778
# 4            7.800000     0.175278
# ...               ...          ...
# 1499995      6.850000     0.050278
# 1499996      6.800000     0.036944
# 1499997     12.350000     0.164722
# 1499998     16.559999     0.271111
# 1499999     11.000000     0.150000
#
# [1500000 rows x 16 columns]

# %% [markdown]
# ## Limiting the variables' values

# %%
# To clean the data, we will remove rows with missing values and outliers by filtering the data on specific conditions (explained in the report)
print(f"Dataframe shape before cleaning: {df_trips.shape}")

df_trips_filtered = df_trips.loc[
    (df_trips['trip_distance'] < 21.0) & 
    (df_trips['trip_distance'] > 0.2) & 
    (df_trips['dropoff_longitude'] <= -73) & 
    (df_trips['dropoff_longitude'] > -75) & 
    (df_trips['dropoff_latitude'] >= 40) & 
    (df_trips['dropoff_latitude'] < 42) &
    (df_trips['pickup_longitude'] <= -73) & 
    (df_trips['pickup_longitude'] > -75) & 
    (df_trips['pickup_latitude'] >= 40) & 
    (df_trips['pickup_latitude'] < 42) &
    (df_trips['time_length'] > 0.02)
]

print(f"Dataframe shape after cleaning: {df_trips_filtered.shape}")
# Out:
# Dataframe shape before cleaning: (1500000, 16)
# Dataframe shape after cleaning: (1450228, 16)

# %% [markdown]
# # Predictive model - distance cost matrix

# %% [markdown]
# ## Data splitting

# %%
inputs = df_trips_filtered[['pickup_longitude', 'pickup_latitude','dropoff_longitude', 'dropoff_latitude']]
labelDistance = df_trips_filtered['trip_distance']

x_trainDistance, x_testDistance, y_trainDistance, y_testDistance = train_test_split(inputs, labelDistance, random_state=69)

# %% [markdown]
# ## Choice of regression model

# %% [markdown]
# ### Comparison of possible regression models

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor
from sklearn.linear_model import Ridge, Lasso, ElasticNet, BayesianRidge
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# %%
# List of models for comparison
models = [
    ('Linear Regression', LinearRegression()),
    ('Random Forest Regression', RandomForestRegressor()),
    ('Decision Tree Regression', DecisionTreeRegressor()),
    ('K-Nearest Neighbors Regression', KNeighborsRegressor()),
    ('Gradient Boosting Regression', GradientBoostingRegressor()),
    ('AdaBoost Regression', AdaBoostRegressor()),
    ('Ridge Regression', Ridge()),
    ('Lasso Regression', Lasso()),
    ('Elastic Net Regression', ElasticNet()),
    ('Bayesian Regression', BayesianRidge()),
    ('Polynomial Regression', make_pipeline(PolynomialFeatures(degree=2), LinearRegression()))
]

# Loop through models and calculate MAE
for name, model in models:
    model.fit(x_trainDistance, y_trainDistance)
    y_pred = model.predict(x_testDistance)
    mae = mean_absolute_error(y_testDistance, y_pred)
    print(f"{name} MAE: {mae}")
# Out:
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:522: RuntimeWarning: overflow encountered in cast
#   scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:522: RuntimeWarning: overflow encountered in cast
#   scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
# Linear Regression MAE: 2.580078125
# Random Forest Regression MAE: 0.781791186856506
# Decision Tree Regression MAE: 0.7819644427577508
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:522: RuntimeWarning: overflow encountered in cast
#   scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:522: RuntimeWarning: overflow encountered in cast
#   scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
# K-Nearest Neighbors Regression MAE: 0.9677734375
# Gradient Boosting Regression MAE: 0.8587367929428915
# AdaBoost Regression MAE: 1.4857064043582806
# Ridge Regression MAE: 1.7682638782570488
# Lasso Regression MAE: 2.1294448519861464
# Elastic Net Regression MAE: 2.1294448519861464
# Bayesian Regression MAE: 1.7683034922031813
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:522: RuntimeWarning: overflow encountered in cast
#   scl = avg_as_array.dtype.type(a.size/avg_as_array.size)
# Polynomial Regression MAE: 1.55078125
# c:\Users\Damo\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\function_base.py:522: RuntimeWarning: overflow encountered in cast
#   scl = avg_as_array.dtype.type(a.size/avg_as_array.size)

# %% [markdown]
# ### Comparison Result
# As can be seen from above, the RF regression model is the most accurate. This will therefore be the model that will be kept for the rest of this code.

# %% [markdown]
# ## Final model training

# %%
# Train chosen model
finModelDistance = RandomForestRegressor()
finModelDistance.fit(x_trainDistance, y_trainDistance)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### Importing depot and shop coordinates

# %%
# Depot coordinates and DF
depot_long = -73.941868
depot_lat = 40.725516
df_depot = pd.DataFrame({'id':'Depot', 'lat': [depot_lat], 'long': [depot_long]})

# Shops' coordinates and DF
df_shops = pd.read_csv('2015_shop_locations.csv')
df_shops = df_shops.drop(columns=['demand(kg)', 'stage'])

# Create new df that concatenates depot coordinates with df_shops
df_points = pd.concat([df_depot, df_shops], ignore_index=True)
df_points
# Out:
#                               id        lat       long
# 0                          Depot  40.725516 -73.941868
# 1    ChIJwTC7A55ZwokRPNX9g7ngbaI  40.730837 -73.983194
# 2    ChIJU1XImaNZwokRutunetC8XeE  40.740454 -73.991268
# 3    ChIJG7L-TLVbwokRT36uIrwz2Mo  40.694957 -73.982865
# 4    ChIJ5cPkuBtgwokRn55JgpGqjFA  40.757522 -73.834352
# ..                           ...        ...        ...
# 216  ChIJ3wsoxKFZwokRRg8OvEjE0bc  40.736716 -73.986817
# 217  ChIJQRpR6Jj0wokRl9myJ19eEvU  40.850804 -73.867450
# 218  ChIJQYmJtx5awokR45_sopkXVNE  40.715137 -74.011088
# 219  ChIJh4MG8h9awokR1kDLslu2C3E  40.718249 -74.007346
# 220  ChIJbdnGmlxewokRobPWHJXQVjM  40.725204 -73.879608
#
# [221 rows x 3 columns]

# %% [markdown]
# ### Distance cost matrix

# %%
# Predict the cost matrix using every couple of ids in df_points
## First create a new df for the cost matrix
costMatrixDistance = pd.DataFrame(columns=df_points['id'], index=df_points['id'])

## Second fill the cost matrix with the predicted values
for id1 in df_points['id']:
    # Get the latitude and longitude for id1
    lat1 = df_points.loc[df_points['id'] == id1, 'lat'].values[0]
    long1 = df_points.loc[df_points['id'] == id1, 'long'].values[0]
    
    for id2 in df_points['id']:
        # Get the latitude and longitude for id2
        lat2 = df_points.loc[df_points['id'] == id2, 'lat'].values[0]
        long2 = df_points.loc[df_points['id'] == id2, 'long'].values[0]

        costMatrixDistance.loc[id1, id2] = finModelDistance.predict([[long1, lat1, long2, lat2]])[0]

costMatrixDistance
# Out:
# id                               Depot ChIJwTC7A55ZwokRPNX9g7ngbaI  \
# id
# Depot                         1.264695                    3.289752
# ChIJwTC7A55ZwokRPNX9g7ngbaI   3.652491                    1.293245
# ChIJU1XImaNZwokRutunetC8XeE   5.344794                    2.462545
# ChIJG7L-TLVbwokRT36uIrwz2Mo   4.159567                    2.779143
# ChIJ5cPkuBtgwokRn55JgpGqjFA    8.44885                   13.636841
# ...                                ...                         ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc   5.344794                    2.462545
# ChIJQRpR6Jj0wokRl9myJ19eEvU  13.048655                   12.831094
# ChIJQYmJtx5awokR45_sopkXVNE   3.652491                    1.293245
# ChIJh4MG8h9awokR1kDLslu2C3E   3.652491                    1.293245
# ChIJbdnGmlxewokRobPWHJXQVjM   4.337399                    9.527067
#
# id                          ChIJU1XImaNZwokRutunetC8XeE  \
# id
# Depot                                          5.079517
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    2.402347
# ChIJU1XImaNZwokRutunetC8XeE                    1.223754
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    5.555309
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   10.780676
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    1.223754
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    7.774905
# ChIJQYmJtx5awokR45_sopkXVNE                    2.402347
# ChIJh4MG8h9awokR1kDLslu2C3E                    2.402347
# ChIJbdnGmlxewokRobPWHJXQVjM                    7.675381
#
# id                          ChIJG7L-TLVbwokRT36uIrwz2Mo  \
# id
# Depot                                          4.125355
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    3.398711
# ChIJU1XImaNZwokRutunetC8XeE                    5.815233
# ChIJG7L-TLVbwokRT36uIrwz2Mo                     1.35245
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   12.250608
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    5.815233
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    8.075834
# ChIJQYmJtx5awokR45_sopkXVNE                    3.398711
# ChIJh4MG8h9awokR1kDLslu2C3E                    3.398711
# ChIJbdnGmlxewokRobPWHJXQVjM                    9.885288
#
# id                          ChIJ5cPkuBtgwokRn55JgpGqjFA  \
# id
# Depot                                          9.565742
# ChIJwTC7A55ZwokRPNX9g7ngbaI                   13.306269
# ChIJU1XImaNZwokRutunetC8XeE                   12.162233
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   14.815639
# ChIJ5cPkuBtgwokRn55JgpGqjFA                    2.086402
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                   12.162233
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    6.662563
# ChIJQYmJtx5awokR45_sopkXVNE                   13.306269
# ChIJh4MG8h9awokR1kDLslu2C3E                   13.306269
# ChIJbdnGmlxewokRobPWHJXQVjM                     4.06927
#
# id                          ChIJ24V7r_31wokR-S71l2zqrwc  \
# id
# Depot                                          6.672981
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    5.361937
# ChIJU1XImaNZwokRutunetC8XeE                    2.746551
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    8.422352
# ChIJ5cPkuBtgwokRn55JgpGqjFA                    4.636728
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    2.746551
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    5.516532
# ChIJQYmJtx5awokR45_sopkXVNE                    5.361937
# ChIJh4MG8h9awokR1kDLslu2C3E                    5.361937
# ChIJbdnGmlxewokRobPWHJXQVjM                    7.023282
#
# id                          ChIJiUJ1DI5ZwokRWdK6SPg9BOY  \
# id
# Depot                                          3.289752
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    1.293245
# ChIJU1XImaNZwokRutunetC8XeE                    2.462545
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    2.779143
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   13.636841
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    2.462545
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   12.831094
# ChIJQYmJtx5awokR45_sopkXVNE                    1.293245
# ChIJh4MG8h9awokR1kDLslu2C3E                    1.293245
# ChIJbdnGmlxewokRobPWHJXQVjM                    9.527067
#
# id                          ChIJYTxm0Gf2wokR5V0iFDQ-2x0  \
# id
# Depot                                         10.293884
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    7.911147
# ChIJU1XImaNZwokRutunetC8XeE                    5.210559
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   10.851788
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   11.720111
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    5.210559
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    3.592429
# ChIJQYmJtx5awokR45_sopkXVNE                    7.911147
# ChIJh4MG8h9awokR1kDLslu2C3E                    7.911147
# ChIJbdnGmlxewokRobPWHJXQVjM                    8.795956
#
# id                          ChIJ_eQYpFdmwokR756MAH2tZPw  \
# id
# Depot                                         15.466988
# ChIJwTC7A55ZwokRPNX9g7ngbaI                   17.828954
# ChIJU1XImaNZwokRutunetC8XeE                   16.860678
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   17.045178
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   10.178064
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                   16.860678
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   15.030873
# ChIJQYmJtx5awokR45_sopkXVNE                   17.828954
# ChIJh4MG8h9awokR1kDLslu2C3E                   17.828954
# ChIJbdnGmlxewokRobPWHJXQVjM                    9.963587
#
# id                          ChIJYzaRC2REwokRaH2rHpflSYk  ...  \
# id                                                       ...
# Depot                                         13.913255  ...
# ChIJwTC7A55ZwokRPNX9g7ngbaI                   13.407891  ...
# ChIJU1XImaNZwokRutunetC8XeE                   15.701421  ...
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   10.390874  ...
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   13.210052  ...
# ...                                                 ...  ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                   15.701421  ...
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   19.568436  ...
# ChIJQYmJtx5awokR45_sopkXVNE                   13.407891  ...
# ChIJh4MG8h9awokR1kDLslu2C3E                   13.407891  ...
# ChIJbdnGmlxewokRobPWHJXQVjM                   13.944209  ...
#
# id                          ChIJReQHww5FwokRGlFWAkn4opg  \
# id
# Depot                                         13.804221
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    12.55492
# ChIJU1XImaNZwokRutunetC8XeE                   14.875472
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    9.036164
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   17.468174
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                   14.875472
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   19.109784
# ChIJQYmJtx5awokR45_sopkXVNE                    12.55492
# ChIJh4MG8h9awokR1kDLslu2C3E                    12.55492
# ChIJbdnGmlxewokRobPWHJXQVjM                   17.471596
#
# id                          ChIJQwtmq3v2wokRNOjx5cEBhXg  \
# id
# Depot                                         10.293884
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    7.911147
# ChIJU1XImaNZwokRutunetC8XeE                    5.210559
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   10.851788
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   11.720111
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    5.210559
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    3.592429
# ChIJQYmJtx5awokR45_sopkXVNE                    7.911147
# ChIJh4MG8h9awokR1kDLslu2C3E                    7.911147
# ChIJbdnGmlxewokRobPWHJXQVjM                    8.795956
#
# id                          ChIJt2vTu1lawokRfVV3pBzItgU  \
# id
# Depot                                          4.125355
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    3.398711
# ChIJU1XImaNZwokRutunetC8XeE                    5.815233
# ChIJG7L-TLVbwokRT36uIrwz2Mo                     1.35245
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   12.266233
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    5.815233
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    8.075834
# ChIJQYmJtx5awokR45_sopkXVNE                    3.398711
# ChIJh4MG8h9awokR1kDLslu2C3E                    3.398711
# ChIJbdnGmlxewokRobPWHJXQVjM                    9.885288
#
# id                          ChIJX9DK2EBEwokRM9kDwjBVtag  \
# id
# Depot                                         15.535282
# ChIJwTC7A55ZwokRPNX9g7ngbaI                   17.193343
# ChIJU1XImaNZwokRutunetC8XeE                   17.368442
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   14.318078
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   13.210052
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                   17.368442
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   19.568436
# ChIJQYmJtx5awokR45_sopkXVNE                   17.193343
# ChIJh4MG8h9awokR1kDLslu2C3E                   17.193343
# ChIJbdnGmlxewokRobPWHJXQVjM                   13.944209
#
# id                          ChIJmZKM98dgwokRZ6ZvctE2ImQ  \
# id
# Depot                                         10.225981
# ChIJwTC7A55ZwokRPNX9g7ngbaI                   14.015943
# ChIJU1XImaNZwokRutunetC8XeE                   13.057781
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   13.400577
# ChIJ5cPkuBtgwokRn55JgpGqjFA                    6.411415
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                   13.057781
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    8.429137
# ChIJQYmJtx5awokR45_sopkXVNE                   14.015943
# ChIJh4MG8h9awokR1kDLslu2C3E                   14.015943
# ChIJbdnGmlxewokRobPWHJXQVjM                    3.240562
#
# id                          ChIJ3wsoxKFZwokRRg8OvEjE0bc  \
# id
# Depot                                          5.079517
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    2.402347
# ChIJU1XImaNZwokRutunetC8XeE                    1.223754
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    5.555309
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   10.780676
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    1.223754
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    7.774905
# ChIJQYmJtx5awokR45_sopkXVNE                    2.402347
# ChIJh4MG8h9awokR1kDLslu2C3E                    2.402347
# ChIJbdnGmlxewokRobPWHJXQVjM                    7.675381
#
# id                          ChIJQRpR6Jj0wokRl9myJ19eEvU  \
# id
# Depot                                         14.802674
# ChIJwTC7A55ZwokRPNX9g7ngbaI                   13.395202
# ChIJU1XImaNZwokRutunetC8XeE                    11.57671
# ChIJG7L-TLVbwokRT36uIrwz2Mo                   16.376429
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   15.669211
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    11.57671
# ChIJQRpR6Jj0wokRl9myJ19eEvU                    1.876177
# ChIJQYmJtx5awokR45_sopkXVNE                   13.395202
# ChIJh4MG8h9awokR1kDLslu2C3E                   13.395202
# ChIJbdnGmlxewokRobPWHJXQVjM                   13.873058
#
# id                          ChIJQYmJtx5awokR45_sopkXVNE  \
# id
# Depot                                          3.289752
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    1.293245
# ChIJU1XImaNZwokRutunetC8XeE                    2.462545
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    2.779143
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   13.636841
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    2.462545
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   12.831094
# ChIJQYmJtx5awokR45_sopkXVNE                    1.293245
# ChIJh4MG8h9awokR1kDLslu2C3E                    1.293245
# ChIJbdnGmlxewokRobPWHJXQVjM                    9.527067
#
# id                          ChIJh4MG8h9awokR1kDLslu2C3E  \
# id
# Depot                                          3.289752
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    1.293245
# ChIJU1XImaNZwokRutunetC8XeE                    2.462545
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    2.779143
# ChIJ5cPkuBtgwokRn55JgpGqjFA                   13.636841
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    2.462545
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   12.831094
# ChIJQYmJtx5awokR45_sopkXVNE                    1.293245
# ChIJh4MG8h9awokR1kDLslu2C3E                    1.293245
# ChIJbdnGmlxewokRobPWHJXQVjM                    9.527067
#
# id                          ChIJbdnGmlxewokRobPWHJXQVjM
# id
# Depot                                          3.899394
# ChIJwTC7A55ZwokRPNX9g7ngbaI                    9.058113
# ChIJU1XImaNZwokRutunetC8XeE                    8.268289
# ChIJG7L-TLVbwokRT36uIrwz2Mo                    9.556437
# ChIJ5cPkuBtgwokRn55JgpGqjFA                    3.369102
# ...                                                 ...
# ChIJ3wsoxKFZwokRRg8OvEjE0bc                    8.268289
# ChIJQRpR6Jj0wokRl9myJ19eEvU                   15.773412
# ChIJQYmJtx5awokR45_sopkXVNE                    9.058113
# ChIJh4MG8h9awokR1kDLslu2C3E                    9.058113
# ChIJbdnGmlxewokRobPWHJXQVjM                    1.736299
#
# [221 rows x 221 columns]

# %% [markdown]
# # Predictive model - duration cost matrix

# %% [markdown]
# ## Data splitting

# %%
labelTime = df_trips_filtered['time_length']

x_trainTime, x_testTime, y_trainTime, y_testTime = train_test_split(inputs, labelTime, random_state=420)

# %% [markdown]
# ## Final model training

# %%
# Train chosen model
finModelDuration = RandomForestRegressor()
finModelDuration.fit(x_trainTime, y_trainTime)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### Importing depot and shop coordinates

# %%
# Depot coordinates and DF
depot_long = -73.941868
depot_lat = 40.725516
df_depot = pd.DataFrame({'id':'Depot', 'lat': [depot_lat], 'long': [depot_long]})

# Shops' coordinates and DF
df_shops = pd.read_csv('2015_shop_locations.csv')
df_shops = df_shops.drop(columns=['demand(kg)', 'stage'])

# Create new df that concatenates depot coordinates with df_shops
df_points = pd.concat([df_depot, df_shops], ignore_index=True)
df_points
# Out:
#                               id        lat       long
# 0                          Depot  40.725516 -73.941868
# 1    ChIJwTC7A55ZwokRPNX9g7ngbaI  40.730837 -73.983194
# 2    ChIJU1XImaNZwokRutunetC8XeE  40.740454 -73.991268
# 3    ChIJG7L-TLVbwokRT36uIrwz2Mo  40.694957 -73.982865
# 4    ChIJ5cPkuBtgwokRn55JgpGqjFA  40.757522 -73.834352
# ..                           ...        ...        ...
# 216  ChIJ3wsoxKFZwokRRg8OvEjE0bc  40.736716 -73.986817
# 217  ChIJQRpR6Jj0wokRl9myJ19eEvU  40.850804 -73.867450
# 218  ChIJQYmJtx5awokR45_sopkXVNE  40.715137 -74.011088
# 219  ChIJh4MG8h9awokR1kDLslu2C3E  40.718249 -74.007346
# 220  ChIJbdnGmlxewokRobPWHJXQVjM  40.725204 -73.879608
#
# [221 rows x 3 columns]

# %% [markdown]
# ### Duration cost matrix

# %%
# Predict the cost matrix using every couple of ids in df_points
## First create a new df for the cost matrix
costMatrixDuration = pd.DataFrame(columns=df_points['id'], index=df_points['id'])

## Second fill the cost matrix with the predicted values
for id1 in df_points['id']:
    # Get the latitude and longitude for id1
    lat1 = df_points.loc[df_points['id'] == id1, 'lat'].values[0]
    long1 = df_points.loc[df_points['id'] == id1, 'long'].values[0]
    
    for id2 in df_points['id']:
        # Get the latitude and longitude for id2
        lat2 = df_points.loc[df_points['id'] == id2, 'lat'].values[0]
        long2 = df_points.loc[df_points['id'] == id2, 'long'].values[0]

        costMatrixDuration.loc[id1, id2] = finModelDuration.predict([[long1, lat1, long2, lat2]])[0]

costMatrixDuration

# %% [markdown]
# # Predictive model - financial cost matrix

# %% [markdown]
# ## Data splitting

# %%
labelFinancial = df_trips_filtered['time_length']

x_trainFinancial, x_testFinancial, y_trainFinancial, y_testFinancial = train_test_split(inputs, labelFinancial, random_state=420)

# %% [markdown]
# ## Final model training

# %%
# Train chosen model
finModelFinancial = RandomForestRegressor()
finModelFinancial.fit(x_trainFinancial, y_trainFinancial)
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## Predictions

# %% [markdown]
# ### Importing depot and shop coordinates

# %%
# Depot coordinates and DF
depot_long = -73.941868
depot_lat = 40.725516
df_depot = pd.DataFrame({'id':'Depot', 'lat': [depot_lat], 'long': [depot_long]})

# Shops' coordinates and DF
df_shops = pd.read_csv('2015_shop_locations.csv')
df_shops = df_shops.drop(columns=['demand(kg)', 'stage'])

# Create new df that concatenates depot coordinates with df_shops
df_points = pd.concat([df_depot, df_shops], ignore_index=True)
df_points
# Out:
#                               id        lat       long
# 0                          Depot  40.725516 -73.941868
# 1    ChIJwTC7A55ZwokRPNX9g7ngbaI  40.730837 -73.983194
# 2    ChIJU1XImaNZwokRutunetC8XeE  40.740454 -73.991268
# 3    ChIJG7L-TLVbwokRT36uIrwz2Mo  40.694957 -73.982865
# 4    ChIJ5cPkuBtgwokRn55JgpGqjFA  40.757522 -73.834352
# ..                           ...        ...        ...
# 216  ChIJ3wsoxKFZwokRRg8OvEjE0bc  40.736716 -73.986817
# 217  ChIJQRpR6Jj0wokRl9myJ19eEvU  40.850804 -73.867450
# 218  ChIJQYmJtx5awokR45_sopkXVNE  40.715137 -74.011088
# 219  ChIJh4MG8h9awokR1kDLslu2C3E  40.718249 -74.007346
# 220  ChIJbdnGmlxewokRobPWHJXQVjM  40.725204 -73.879608
#
# [221 rows x 3 columns]

# %% [markdown]
# ### Financial cost matrix

# %%
# Predict the cost matrix using every couple of ids in df_points
## First create a new df for the cost matrix
costMatrixFinancial = pd.DataFrame(columns=df_points['id'], index=df_points['id'])

## Second fill the cost matrix with the predicted values
for id1 in df_points['id']:
    # Get the latitude and longitude for id1
    lat1 = df_points.loc[df_points['id'] == id1, 'lat'].values[0]
    long1 = df_points.loc[df_points['id'] == id1, 'long'].values[0]
    
    for id2 in df_points['id']:
        # Get the latitude and longitude for id2
        lat2 = df_points.loc[df_points['id'] == id2, 'lat'].values[0]
        long2 = df_points.loc[df_points['id'] == id2, 'long'].values[0]

        costMatrixFinancial.loc[id1, id2] = finModelFinancial.predict([[long1, lat1, long2, lat2]])[0]

costMatrixFinancial
