# %%
import numpy as np
import pandas as pd
import requests

# %%
#url = 'https://perso.liris.cnrs.fr/lmoncla/GI-5-IFU/'
filename = 'trips2015_1.5M.csv.zip'
#
#r = requests.get(url + filename)
#open(filename, 'wb').write(r.content)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\.conda\envs\IFU\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\.conda\envs\IFU\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\.conda\envs\IFU\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %%
df = pd.read_csv(filename)
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-06-03 10:41:50   2015-06-03 11:08:33                1
# 1         2  2015-02-14 19:38:55   2015-02-14 20:00:59                1
# 2         2  2015-04-21 15:21:04   2015-04-21 15:33:38                1
# 3         2  2015-01-29 18:58:54   2015-01-29 19:04:46                3
# 4         1  2015-06-05 10:47:29   2015-06-05 10:58:00                3
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           2.80        -73.952888        40.776814           1
# 1           2.79        -73.995827        40.725353           1
# 2           1.75        -73.951920        40.769421           1
# 3           0.83        -74.009026        40.715710           1
# 4           0.80        -73.985909        40.756176           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...
